# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Imports</h2>
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
# For ML Models
from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import EfficientNetV2B0
from tensorflow.keras.applications import EfficientNetV2B3
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report,confusion_matrix
import ipywidgets as widgets
import io
from PIL import Image
from IPython.display import display,clear_output
from warnings import filterwarnings
import splitfolders
import warnings
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from prettytable import PrettyTable
from tensorflow.keras.utils import to_categorical
from tqdm import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'matplotlib'

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Seed</h2>
# </div>

# %%
tf.random.set_seed(42)
# np.rando.set_seed(42)

# %%
colors_dark = ["#1F1F1F", "#313131", '#636363', '#AEAEAE', '#DADADA']
colors_red = ["#331313", "#582626", '#9E1717', '#D35151', '#E9B4B4']
colors_green = ['#01411C','#4B6F44','#4F7942','#74C365','#D0F0C0']

sns.palplot(colors_dark)
sns.palplot(colors_green)
sns.palplot(colors_red)

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Data Import and split 80-20</h2>
# </div>

# %%
labels = ['glioma','notumor','meningioma','pituitary']

# %%
TRAIN_DIR = r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\StrategicThinkingCA3-\\MedicalImages\\Training'
splitfolders.ratio(TRAIN_DIR, output="DataSplit", ratio=(0.8, 0.2))
# Out:
# Copying files: 5712 files [00:19, 296.82 files/s]

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\','x_train80%',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
  
 
    
X_val = []
y_val = []
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\','y_train20%',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_val.append(img)
        y_val.append(i)
        

X_test = []
y_test = []
        
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\MedicalImages\\','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_test.append(img)
        y_test.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)
# Out:
# 100%|██████████| 1056/1056 [00:04<00:00, 244.52it/s]
# 100%|██████████| 1276/1276 [00:04<00:00, 256.60it/s]
# 100%|██████████| 1071/1071 [00:04<00:00, 220.45it/s]
# 100%|██████████| 1165/1165 [00:05<00:00, 224.39it/s]
# 100%|██████████| 265/265 [00:00<00:00, 278.96it/s]
# 100%|██████████| 319/319 [00:01<00:00, 271.53it/s]
# 100%|██████████| 268/268 [00:01<00:00, 234.47it/s]
# 100%|██████████| 292/292 [00:01<00:00, 227.58it/s]
# 100%|██████████| 300/300 [00:01<00:00, 285.84it/s]
# 100%|██████████| 405/405 [00:01<00:00, 363.25it/s]
# 100%|██████████| 306/306 [00:01<00:00, 283.30it/s]
# 100%|██████████| 300/300 [00:01<00:00, 247.36it/s]

# %%
print('Training 80%')
print(X_train.shape)
print('Training 20%')
print(X_val.shape)
print('Test')
print(X_test.shape)
# Out:
# Training 80%
# (4568, 150, 150, 3)
# Training 20%
# (1144, 150, 150, 3)
# Test
# (1311, 150, 150, 3)

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Show train data in charts</h2>
# </div>

# %%
# Get the number of images for each label from the Counter dictionaries
notumor_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\x_train80%\\notumor')
glioma_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\StrategicThinkingCA3-\\DataSplit\\x_train80%\\glioma')
meningioma_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\x_train80%\\meningioma')
pituitary_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\x_train80%\\pituitary')

# Create a list of numerical values that represent the number of images for each label
sizes = [notumor_count, glioma_count, meningioma_count, pituitary_count]

# Set up the plot
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie(sizes, colors=colors, autopct='%.1f%%', explode=(0.05,0,0,0),
        startangle=30);

# Add labels to the plot
labels = ['No Tumor', 'Glioma', 'Meningioma', 'Pituitary']
plt.legend(labels, loc='best')
plt.axis('equal')
plt.title('Distribution of Images in Training Set')
plt.show()

# %%
# Get the number of images for each label from the Counter dictionaries
notumor_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\y_train20%\\notumor')
glioma_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\StrategicThinkingCA3-\\DataSplit\\y_train20%\\glioma')
meningioma_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\y_train20%\\meningioma')
pituitary_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\y_train20%\\pituitary')

# Create a list of numerical values that represent the number of images for each label
sizes = [notumor_count, glioma_count, meningioma_count, pituitary_count]

# Set up the plot
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie(sizes, colors=colors, autopct='%.1f%%', explode=(0.05,0,0,0),
        startangle=30);

# Add labels to the plot
labels = ['No Tumor', 'Glioma', 'Meningioma', 'Pituitary']
plt.legend(labels, loc='best')
plt.axis('equal')
plt.title('Distribution of Images in Val Set')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 sizes = [notumor_count, glioma_count, meningioma_count, pituitary_count]
#      10 # Set up the plot
# ---> 11 plt.figure(figsize=(14,6))
#      12 colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
#      13 plt.rcParams.update({'font.size': 14})
#
# NameError: name 'plt' is not defined

# %%
# Get the number of images for each label from the Counter dictionaries
notumor_count = len(r'C:\Users\eduma\OneDrive\Escritorio\CA3\StrategicThinkingCA3-\MedicalImages\Testing\\notumor')
glioma_count = len(r'C:\Users\eduma\OneDrive\Escritorio\CA3\StrategicThinkingCA3-\MedicalImages\Testing\\glioma')
meningioma_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\MedicalImages\\Testing\\meningioma')
pituitary_count = len(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\MedicalImages\\Testing\\pituitary')

# Create a list of numerical values that represent the number of images for each label
sizes = [notumor_count, glioma_count, meningioma_count, pituitary_count]

# Set up the plot
plt.figure(figsize=(14,6))
colors = ['#4285f4', '#ea4335', '#fbbc05', '#34a853']
plt.rcParams.update({'font.size': 14})
plt.pie(sizes, colors=colors, autopct='%.1f%%', explode=(0.05,0,0,0),
        startangle=30);

# Add labels to the plot
labels = ['No Tumor', 'Glioma', 'Meningioma', 'Pituitary']
plt.legend(labels, loc='best')
plt.axis('equal')
plt.title('Distribution of Images in Test Set')
plt.show()

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">One-Hot Encoding</h2>
# </div>

# %%
y_train_new = []
for i in y_train:
 y_train_new.append(labels.index(i))

y_train = tf.keras.utils.to_categorical(y_train_new)
y_val_new = []
for i in y_val:
 y_val_new.append(labels.index(i))
y_val = tf.keras.utils.to_categorical(y_val_new)
y_test_new = []
for i in y_test:
 y_test_new.append(labels.index(i))
y_test = tf.keras.utils.to_categorical(y_test_new)
# Out:
#   Cell In[2], line 1
#     <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#     ^
# SyntaxError: invalid syntax

# %%
# Scaling Train, Valid and Test Features
X_train_scaled = X_train.astype('float32')
X_val_scaled = X_val.astype('float32')
X_test_scaled = X_test.astype('float32')
X_train_scaled /= 255.
X_val_scaled /= 255.
X_test_scaled /= 255.

# %%
minvalue = np.min(X_train)
maxvalue = np.max(X_train)
minvalues = np.min(X_train_scaled)
maxvalues = np.max(X_train_scaled)
print(minvalue)
print(maxvalue)
print(minvalues)
print(maxvalues)

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Generic values</h2>
# </div>

# %%
batch_size = 32              # Batch size for training and validation
num_classes = 4             # Number of classes in the dataset

# %%
datagen = ImageDataGenerator(horizontal_flip=True)

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ResNet50</h2>
# </div>

# %%
# Loading the pre-trained ResNet50 model without the top classification layer
res_model = ResNet50(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)

# Freezing the layers of the pre-trained model
for layer in res_model.layers:
    layer.trainable = False

# Building the new model
model = Sequential()
model.add(res_model)
model.add(Flatten())
model.add(Dense(4, activation='softmax'))  # 4 classes in the output layer

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# %%
# Defining the checkpoint
filepath = "weightsbestTesNet50100%scaled.keras"  # Updated extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
historyres = model.fit(datagen.flow(X_train_scaled, y_train, batch_size=32),
validation_data=(X_val_scaled, y_val),
batch_size=32,
epochs=20,
callbacks=callbacks_list)
# Out:
# Epoch 1/20
# c:\Users\eduma\OneDrive\Escritorio\CA3\test\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.5335 - loss: 1.1844
# Epoch 1: val_categorical_accuracy improved from -inf to 0.73864, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 284s 2s/step - categorical_accuracy: 0.5341 - loss: 1.1826 - val_categorical_accuracy: 0.7386 - val_loss: 0.6655
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7212 - loss: 0.7114
# Epoch 2: val_categorical_accuracy improved from 0.73864 to 0.74563, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - categorical_accuracy: 0.7212 - loss: 0.7112 - val_categorical_accuracy: 0.7456 - val_loss: 0.6126
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 977ms/step - categorical_accuracy: 0.7546 - loss: 0.6088
# Epoch 3: val_categorical_accuracy improved from 0.74563 to 0.80420, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - categorical_accuracy: 0.7546 - loss: 0.6087 - val_categorical_accuracy: 0.8042 - val_loss: 0.5233
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - categorical_accuracy: 0.7781 - loss: 0.5616
# Epoch 4: val_categorical_accuracy did not improve from 0.80420
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - categorical_accuracy: 0.7781 - loss: 0.5616 - val_categorical_accuracy: 0.7972 - val_loss: 0.5338
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 949ms/step - categorical_accuracy: 0.7598 - loss: 0.6162
# Epoch 5: val_categorical_accuracy did not improve from 0.80420
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - categorical_accuracy: 0.7599 - loss: 0.6159 - val_categorical_accuracy: 0.7876 - val_loss: 0.5365
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - categorical_accuracy: 0.8230 - loss: 0.4745
# Epoch 6: val_categorical_accuracy did not improve from 0.80420
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - categorical_accuracy: 0.8229 - loss: 0.4746 - val_categorical_accuracy: 0.7832 - val_loss: 0.5185
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 966ms/step - categorical_accuracy: 0.8108 - loss: 0.4820
# Epoch 7: val_categorical_accuracy improved from 0.80420 to 0.83479, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - categorical_accuracy: 0.8108 - loss: 0.4819 - val_categorical_accuracy: 0.8348 - val_loss: 0.4456
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - categorical_accuracy: 0.8312 - loss: 0.4386
# Epoch 8: val_categorical_accuracy improved from 0.83479 to 0.84178, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - categorical_accuracy: 0.8312 - loss: 0.4386 - val_categorical_accuracy: 0.8418 - val_loss: 0.4501
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 950ms/step - categorical_accuracy: 0.8295 - loss: 0.4371
# Epoch 9: val_categorical_accuracy did not improve from 0.84178
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - categorical_accuracy: 0.8294 - loss: 0.4371 - val_categorical_accuracy: 0.7885 - val_loss: 0.4966
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 955ms/step - categorical_accuracy: 0.8600 - loss: 0.3716
# Epoch 10: val_categorical_accuracy did not improve from 0.84178
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - categorical_accuracy: 0.8599 - loss: 0.3718 - val_categorical_accuracy: 0.7605 - val_loss: 0.6316
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - categorical_accuracy: 0.8122 - loss: 0.4793
# Epoch 11: val_categorical_accuracy did not improve from 0.84178
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - categorical_accuracy: 0.8122 - loss: 0.4793 - val_categorical_accuracy: 0.8051 - val_loss: 0.4923
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - categorical_accuracy: 0.8328 - loss: 0.4373
# Epoch 12: val_categorical_accuracy improved from 0.84178 to 0.85577, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - categorical_accuracy: 0.8328 - loss: 0.4374 - val_categorical_accuracy: 0.8558 - val_loss: 0.3977
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - categorical_accuracy: 0.8271 - loss: 0.4185
# Epoch 13: val_categorical_accuracy did not improve from 0.85577
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - categorical_accuracy: 0.8272 - loss: 0.4184 - val_categorical_accuracy: 0.8260 - val_loss: 0.4537
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 992ms/step - categorical_accuracy: 0.8392 - loss: 0.4135
# Epoch 14: val_categorical_accuracy did not improve from 0.85577
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - categorical_accuracy: 0.8393 - loss: 0.4134 - val_categorical_accuracy: 0.8418 - val_loss: 0.4347
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - categorical_accuracy: 0.8599 - loss: 0.3696
# Epoch 15: val_categorical_accuracy did not improve from 0.85577
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - categorical_accuracy: 0.8598 - loss: 0.3696 - val_categorical_accuracy: 0.8549 - val_loss: 0.4115
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - categorical_accuracy: 0.8478 - loss: 0.3758
# Epoch 16: val_categorical_accuracy improved from 0.85577 to 0.87063, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - categorical_accuracy: 0.8478 - loss: 0.3760 - val_categorical_accuracy: 0.8706 - val_loss: 0.3733
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 971ms/step - categorical_accuracy: 0.8502 - loss: 0.3833
# Epoch 17: val_categorical_accuracy did not improve from 0.87063
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - categorical_accuracy: 0.8502 - loss: 0.3833 - val_categorical_accuracy: 0.8488 - val_loss: 0.4286
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 979ms/step - categorical_accuracy: 0.8376 - loss: 0.4224
# Epoch 18: val_categorical_accuracy did not improve from 0.87063
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - categorical_accuracy: 0.8377 - loss: 0.4223 - val_categorical_accuracy: 0.8322 - val_loss: 0.4414
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 940ms/step - categorical_accuracy: 0.8655 - loss: 0.3557
# Epoch 19: val_categorical_accuracy did not improve from 0.87063
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - categorical_accuracy: 0.8655 - loss: 0.3557 - val_categorical_accuracy: 0.8479 - val_loss: 0.3975
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 972ms/step - categorical_accuracy: 0.8606 - loss: 0.3569
# Epoch 20: val_categorical_accuracy did not improve from 0.87063
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - categorical_accuracy: 0.8605 - loss: 0.3569 - val_categorical_accuracy: 0.8645 - val_loss: 0.3934

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">VGG16</h2>
# </div>

# %%
# Loading the pre-trained VGG16 model without the top classification layer
v = VGG16(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)

# Freezing the layers of the pre-trained model
for layer in v.layers:
    layer.trainable = False

# Building the new model
model = Sequential()
model.add(v)
model.add(Flatten())
model.add(Dense(4, activation='softmax'))  # 4 classes in the output layer

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Defining the checkpoint
filepath = "weightsbestVGG16100%scaled.keras"  # Updated extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# Fitting the model
historyVGG16 = model.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6640 - loss: 0.8278
# Epoch 1: val_categorical_accuracy improved from -inf to 0.86888, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - categorical_accuracy: 0.6647 - loss: 0.8262 - val_categorical_accuracy: 0.8689 - val_loss: 0.3884
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8572 - loss: 0.4084
# Epoch 2: val_categorical_accuracy improved from 0.86888 to 0.87675, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 292s 2s/step - categorical_accuracy: 0.8573 - loss: 0.4082 - val_categorical_accuracy: 0.8767 - val_loss: 0.3351
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8834 - loss: 0.3148
# Epoch 3: val_categorical_accuracy improved from 0.87675 to 0.89423, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - categorical_accuracy: 0.8834 - loss: 0.3148 - val_categorical_accuracy: 0.8942 - val_loss: 0.3141
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8987 - loss: 0.2866
# Epoch 4: val_categorical_accuracy improved from 0.89423 to 0.90559, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - categorical_accuracy: 0.8986 - loss: 0.2867 - val_categorical_accuracy: 0.9056 - val_loss: 0.2692
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8983 - loss: 0.2753
# Epoch 5: val_categorical_accuracy did not improve from 0.90559
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - categorical_accuracy: 0.8983 - loss: 0.2753 - val_categorical_accuracy: 0.9012 - val_loss: 0.3154
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9077 - loss: 0.2560
# Epoch 6: val_categorical_accuracy did not improve from 0.90559
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - categorical_accuracy: 0.9078 - loss: 0.2559 - val_categorical_accuracy: 0.8977 - val_loss: 0.2675
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9149 - loss: 0.2378
# Epoch 7: val_categorical_accuracy improved from 0.90559 to 0.90909, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - categorical_accuracy: 0.9149 - loss: 0.2378 - val_categorical_accuracy: 0.9091 - val_loss: 0.2537
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9290 - loss: 0.2161
# Epoch 8: val_categorical_accuracy did not improve from 0.90909
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - categorical_accuracy: 0.9290 - loss: 0.2162 - val_categorical_accuracy: 0.8986 - val_loss: 0.2707
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9152 - loss: 0.2139
# Epoch 9: val_categorical_accuracy improved from 0.90909 to 0.91783, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - categorical_accuracy: 0.9152 - loss: 0.2139 - val_categorical_accuracy: 0.9178 - val_loss: 0.2370
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9228 - loss: 0.2079
# Epoch 10: val_categorical_accuracy did not improve from 0.91783
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - categorical_accuracy: 0.9229 - loss: 0.2079 - val_categorical_accuracy: 0.9065 - val_loss: 0.2686
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9360 - loss: 0.1972
# Epoch 11: val_categorical_accuracy did not improve from 0.91783
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - categorical_accuracy: 0.9360 - loss: 0.1972 - val_categorical_accuracy: 0.9143 - val_loss: 0.2349
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9333 - loss: 0.1897
# Epoch 12: val_categorical_accuracy improved from 0.91783 to 0.92133, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 286s 2s/step - categorical_accuracy: 0.9333 - loss: 0.1898 - val_categorical_accuracy: 0.9213 - val_loss: 0.2340
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9348 - loss: 0.1841
# Epoch 13: val_categorical_accuracy did not improve from 0.92133
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - categorical_accuracy: 0.9348 - loss: 0.1841 - val_categorical_accuracy: 0.9187 - val_loss: 0.2360
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9380 - loss: 0.1727
# Epoch 14: val_categorical_accuracy did not improve from 0.92133
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 289s 2s/step - categorical_accuracy: 0.9380 - loss: 0.1728 - val_categorical_accuracy: 0.9178 - val_loss: 0.2530
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9456 - loss: 0.1677
# Epoch 15: val_categorical_accuracy improved from 0.92133 to 0.92395, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - categorical_accuracy: 0.9455 - loss: 0.1678 - val_categorical_accuracy: 0.9240 - val_loss: 0.2339
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9416 - loss: 0.1562
# Epoch 16: val_categorical_accuracy did not improve from 0.92395
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - categorical_accuracy: 0.9416 - loss: 0.1562 - val_categorical_accuracy: 0.9100 - val_loss: 0.2580
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9371 - loss: 0.1681
# Epoch 17: val_categorical_accuracy did not improve from 0.92395
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - categorical_accuracy: 0.9371 - loss: 0.1680 - val_categorical_accuracy: 0.9152 - val_loss: 0.2360
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9439 - loss: 0.1542
# Epoch 18: val_categorical_accuracy did not improve from 0.92395
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 287s 2s/step - categorical_accuracy: 0.9439 - loss: 0.1542 - val_categorical_accuracy: 0.9047 - val_loss: 0.2678
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9381 - loss: 0.1704
# Epoch 19: val_categorical_accuracy improved from 0.92395 to 0.93007, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 291s 2s/step - categorical_accuracy: 0.9381 - loss: 0.1704 - val_categorical_accuracy: 0.9301 - val_loss: 0.2027
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9458 - loss: 0.1594
# Epoch 20: val_categorical_accuracy did not improve from 0.93007
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 282s 2s/step - categorical_accuracy: 0.9458 - loss: 0.1594 - val_categorical_accuracy: 0.8951 - val_loss: 0.2725

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ResNet50 V2</h2>
# </div>

# %%
rsv2 = ResNet50V2(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)
for layer in rsv2.layers:
    layer.trainable = False

modelrsv2 = Sequential()
modelrsv2.add(rsv2)
modelrsv2.add(Flatten())
modelrsv2.add(Dense(4, activation='softmax'))

modelrsv2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# checkpoint
filepath = "weightsbestResNet50V2100%scaled.keras"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

historyrsv2 = modelrsv2.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 903ms/step - categorical_accuracy: 0.7054 - loss: 3.3761
# Epoch 1: val_categorical_accuracy improved from -inf to 0.83042, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - categorical_accuracy: 0.7061 - loss: 3.3667 - val_categorical_accuracy: 0.8304 - val_loss: 1.7425
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 932ms/step - categorical_accuracy: 0.8701 - loss: 1.1422
# Epoch 2: val_categorical_accuracy improved from 0.83042 to 0.86976, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 168s 1s/step - categorical_accuracy: 0.8701 - loss: 1.1424 - val_categorical_accuracy: 0.8698 - val_loss: 1.5125
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 903ms/step - categorical_accuracy: 0.8775 - loss: 1.2680
# Epoch 3: val_categorical_accuracy improved from 0.86976 to 0.87150, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - categorical_accuracy: 0.8775 - loss: 1.2683 - val_categorical_accuracy: 0.8715 - val_loss: 1.6097
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 908ms/step - categorical_accuracy: 0.8741 - loss: 1.3730
# Epoch 4: val_categorical_accuracy did not improve from 0.87150
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - categorical_accuracy: 0.8742 - loss: 1.3724 - val_categorical_accuracy: 0.8654 - val_loss: 1.8324
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 891ms/step - categorical_accuracy: 0.9008 - loss: 1.0969
# Epoch 5: val_categorical_accuracy improved from 0.87150 to 0.88811, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - categorical_accuracy: 0.9008 - loss: 1.0972 - val_categorical_accuracy: 0.8881 - val_loss: 1.5156
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 916ms/step - categorical_accuracy: 0.9097 - loss: 1.2194
# Epoch 6: val_categorical_accuracy improved from 0.88811 to 0.89685, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - categorical_accuracy: 0.9097 - loss: 1.2187 - val_categorical_accuracy: 0.8969 - val_loss: 1.7655
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 895ms/step - categorical_accuracy: 0.9265 - loss: 0.8805
# Epoch 7: val_categorical_accuracy improved from 0.89685 to 0.92220, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - categorical_accuracy: 0.9265 - loss: 0.8808 - val_categorical_accuracy: 0.9222 - val_loss: 1.5187
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 907ms/step - categorical_accuracy: 0.9241 - loss: 0.9262
# Epoch 8: val_categorical_accuracy did not improve from 0.92220
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - categorical_accuracy: 0.9241 - loss: 0.9268 - val_categorical_accuracy: 0.8837 - val_loss: 1.6681
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 913ms/step - categorical_accuracy: 0.9275 - loss: 0.9104
# Epoch 9: val_categorical_accuracy improved from 0.92220 to 0.93094, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - categorical_accuracy: 0.9275 - loss: 0.9106 - val_categorical_accuracy: 0.9309 - val_loss: 1.1041
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 910ms/step - categorical_accuracy: 0.9313 - loss: 0.9130
# Epoch 10: val_categorical_accuracy did not improve from 0.93094
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - categorical_accuracy: 0.9313 - loss: 0.9139 - val_categorical_accuracy: 0.9196 - val_loss: 1.5216
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 927ms/step - categorical_accuracy: 0.9363 - loss: 0.9308
# Epoch 11: val_categorical_accuracy did not improve from 0.93094
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - categorical_accuracy: 0.9363 - loss: 0.9308 - val_categorical_accuracy: 0.9196 - val_loss: 1.3444
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 904ms/step - categorical_accuracy: 0.9271 - loss: 0.9491
# Epoch 12: val_categorical_accuracy did not improve from 0.93094
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - categorical_accuracy: 0.9272 - loss: 0.9492 - val_categorical_accuracy: 0.9187 - val_loss: 1.6772
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 922ms/step - categorical_accuracy: 0.9425 - loss: 0.8877
# Epoch 13: val_categorical_accuracy improved from 0.93094 to 0.93706, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - categorical_accuracy: 0.9425 - loss: 0.8874 - val_categorical_accuracy: 0.9371 - val_loss: 1.1042
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 896ms/step - categorical_accuracy: 0.9420 - loss: 0.7538
# Epoch 14: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - categorical_accuracy: 0.9420 - loss: 0.7542 - val_categorical_accuracy: 0.9257 - val_loss: 1.2775
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 915ms/step - categorical_accuracy: 0.9325 - loss: 0.8148
# Epoch 15: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - categorical_accuracy: 0.9325 - loss: 0.8152 - val_categorical_accuracy: 0.9301 - val_loss: 1.3673
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 885ms/step - categorical_accuracy: 0.9406 - loss: 0.8909
# Epoch 16: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - categorical_accuracy: 0.9406 - loss: 0.8920 - val_categorical_accuracy: 0.9283 - val_loss: 1.4653
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 912ms/step - categorical_accuracy: 0.9301 - loss: 1.1370
# Epoch 17: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - categorical_accuracy: 0.9301 - loss: 1.1364 - val_categorical_accuracy: 0.9152 - val_loss: 1.8110
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 897ms/step - categorical_accuracy: 0.9415 - loss: 0.9036
# Epoch 18: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 161s 1s/step - categorical_accuracy: 0.9415 - loss: 0.9038 - val_categorical_accuracy: 0.9248 - val_loss: 1.4955
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 920ms/step - categorical_accuracy: 0.9468 - loss: 0.8315
# Epoch 19: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 164s 1s/step - categorical_accuracy: 0.9468 - loss: 0.8318 - val_categorical_accuracy: 0.9231 - val_loss: 1.5821
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 933ms/step - categorical_accuracy: 0.9524 - loss: 0.8089
# Epoch 20: val_categorical_accuracy did not improve from 0.93706
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 166s 1s/step - categorical_accuracy: 0.9523 - loss: 0.8091 - val_categorical_accuracy: 0.9292 - val_loss: 1.2622

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ENV2B0</h2>
# </div>

# %%
# DefinING the model
env2b0 = EfficientNetV2B0(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False, include_preprocessing=False)
for layer in env2b0.layers:
    layer.trainable = False

modelenv2b0 = Sequential()
modelenv2b0.add(env2b0)
modelenv2b0.add(Flatten())
modelenv2b0.add(Dense(4, activation='softmax'))

modelenv2b0.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Checkpoint
filepath = "weightsbestENV2B0100%scaled.keras"  # .keras extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fitting the model
historyenv2b0 = modelenv2b0.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - categorical_accuracy: 0.6967 - loss: 1.2598
# Epoch 1: val_categorical_accuracy improved from -inf to 0.90385, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - categorical_accuracy: 0.6973 - loss: 1.2569 - val_categorical_accuracy: 0.9038 - val_loss: 0.3919
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - categorical_accuracy: 0.8469 - loss: 0.5223
# Epoch 2: val_categorical_accuracy improved from 0.90385 to 0.90734, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 122s 830ms/step - categorical_accuracy: 0.8470 - loss: 0.5221 - val_categorical_accuracy: 0.9073 - val_loss: 0.3017
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - categorical_accuracy: 0.8987 - loss: 0.3778
# Epoch 3: val_categorical_accuracy improved from 0.90734 to 0.91434, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 132s 910ms/step - categorical_accuracy: 0.8986 - loss: 0.3783 - val_categorical_accuracy: 0.9143 - val_loss: 0.4120
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 836ms/step - categorical_accuracy: 0.9076 - loss: 0.3349
# Epoch 4: val_categorical_accuracy did not improve from 0.91434
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 143s 990ms/step - categorical_accuracy: 0.9076 - loss: 0.3350 - val_categorical_accuracy: 0.8698 - val_loss: 0.7446
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 943ms/step - categorical_accuracy: 0.9048 - loss: 0.3921
# Epoch 5: val_categorical_accuracy did not improve from 0.91434
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 165s 1s/step - categorical_accuracy: 0.9047 - loss: 0.3925 - val_categorical_accuracy: 0.8995 - val_loss: 0.5641
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9132 - loss: 0.3438
# Epoch 6: val_categorical_accuracy did not improve from 0.91434
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 178s 1s/step - categorical_accuracy: 0.9132 - loss: 0.3439 - val_categorical_accuracy: 0.9056 - val_loss: 0.5833
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - categorical_accuracy: 0.9123 - loss: 0.3369
# Epoch 7: val_categorical_accuracy improved from 0.91434 to 0.93969, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - categorical_accuracy: 0.9123 - loss: 0.3367 - val_categorical_accuracy: 0.9397 - val_loss: 0.2808
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 741ms/step - categorical_accuracy: 0.9176 - loss: 0.3330
# Epoch 8: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 128s 881ms/step - categorical_accuracy: 0.9176 - loss: 0.3330 - val_categorical_accuracy: 0.9301 - val_loss: 0.2895
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 641ms/step - categorical_accuracy: 0.9316 - loss: 0.2578
# Epoch 9: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 112s 771ms/step - categorical_accuracy: 0.9316 - loss: 0.2578 - val_categorical_accuracy: 0.9266 - val_loss: 0.4151
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - categorical_accuracy: 0.9286 - loss: 0.2993
# Epoch 10: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 113s 779ms/step - categorical_accuracy: 0.9286 - loss: 0.2994 - val_categorical_accuracy: 0.8916 - val_loss: 0.7115
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 691ms/step - categorical_accuracy: 0.9088 - loss: 0.4431
# Epoch 11: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 119s 823ms/step - categorical_accuracy: 0.9088 - loss: 0.4430 - val_categorical_accuracy: 0.9327 - val_loss: 0.3825
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - categorical_accuracy: 0.9134 - loss: 0.4640
# Epoch 12: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 116s 800ms/step - categorical_accuracy: 0.9134 - loss: 0.4637 - val_categorical_accuracy: 0.9318 - val_loss: 0.3856
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - categorical_accuracy: 0.9298 - loss: 0.3409
# Epoch 13: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 134s 926ms/step - categorical_accuracy: 0.9298 - loss: 0.3410 - val_categorical_accuracy: 0.9344 - val_loss: 0.3496
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 705ms/step - categorical_accuracy: 0.9472 - loss: 0.2431
# Epoch 14: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 118s 812ms/step - categorical_accuracy: 0.9472 - loss: 0.2434 - val_categorical_accuracy: 0.8855 - val_loss: 0.6960
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - categorical_accuracy: 0.9354 - loss: 0.3245
# Epoch 15: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 78s 538ms/step - categorical_accuracy: 0.9354 - loss: 0.3244 - val_categorical_accuracy: 0.9397 - val_loss: 0.3742
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - categorical_accuracy: 0.9396 - loss: 0.2739
# Epoch 16: val_categorical_accuracy did not improve from 0.93969
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 78s 534ms/step - categorical_accuracy: 0.9396 - loss: 0.2738 - val_categorical_accuracy: 0.9353 - val_loss: 0.3651
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - categorical_accuracy: 0.9400 - loss: 0.2704
# Epoch 17: val_categorical_accuracy improved from 0.93969 to 0.94843, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 79s 542ms/step - categorical_accuracy: 0.9400 - loss: 0.2706 - val_categorical_accuracy: 0.9484 - val_loss: 0.3036
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step - categorical_accuracy: 0.9329 - loss: 0.3420
# Epoch 18: val_categorical_accuracy did not improve from 0.94843
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 77s 533ms/step - categorical_accuracy: 0.9329 - loss: 0.3420 - val_categorical_accuracy: 0.9406 - val_loss: 0.4315
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step - categorical_accuracy: 0.9315 - loss: 0.3789
# Epoch 19: val_categorical_accuracy did not improve from 0.94843
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 86s 590ms/step - categorical_accuracy: 0.9315 - loss: 0.3785 - val_categorical_accuracy: 0.9292 - val_loss: 0.4507
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - categorical_accuracy: 0.9364 - loss: 0.2926
# Epoch 20: val_categorical_accuracy did not improve from 0.94843
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 119s 821ms/step - categorical_accuracy: 0.9364 - loss: 0.2926 - val_categorical_accuracy: 0.9336 - val_loss: 0.4454

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Personalized</h2>
# </div>

# %%
modelP = Sequential()
modelP.add(Flatten(input_shape=(image_size, image_size, 3)))
modelP.add(Dense(4, activation='softmax'))

modelP.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Define the name of the file for saving the models
filepath = "weightsbestPersonal100%scaled.keras"  # Changed to .keras extension

# Set up ModelCheckpoint
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Train the model
historyPers = modelP.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# c:\Users\eduma\OneDrive\Escritorio\CA3\test\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - categorical_accuracy: 0.3872 - loss: 2.9280
# Epoch 1: val_categorical_accuracy improved from -inf to 0.45717, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 37s 237ms/step - categorical_accuracy: 0.3874 - loss: 2.9228 - val_categorical_accuracy: 0.4572 - val_loss: 1.4807
# Epoch 2/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - categorical_accuracy: 0.4499 - loss: 1.7687
# Epoch 2: val_categorical_accuracy improved from 0.45717 to 0.53409, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 198ms/step - categorical_accuracy: 0.4498 - loss: 1.7727 - val_categorical_accuracy: 0.5341 - val_loss: 1.5642
# Epoch 3/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - categorical_accuracy: 0.4246 - loss: 2.1247
# Epoch 3: val_categorical_accuracy improved from 0.53409 to 0.57780, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 203ms/step - categorical_accuracy: 0.4247 - loss: 2.1251 - val_categorical_accuracy: 0.5778 - val_loss: 1.1253
# Epoch 4/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - categorical_accuracy: 0.4612 - loss: 1.7051
# Epoch 4: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 225ms/step - categorical_accuracy: 0.4611 - loss: 1.7072 - val_categorical_accuracy: 0.5490 - val_loss: 1.4819
# Epoch 5/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - categorical_accuracy: 0.4388 - loss: 2.2238
# Epoch 5: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 240ms/step - categorical_accuracy: 0.4388 - loss: 2.2248 - val_categorical_accuracy: 0.5472 - val_loss: 1.4361
# Epoch 6/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - categorical_accuracy: 0.4427 - loss: 2.1858
# Epoch 6: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 49s 323ms/step - categorical_accuracy: 0.4429 - loss: 2.1850 - val_categorical_accuracy: 0.5052 - val_loss: 1.9232
# Epoch 7/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - categorical_accuracy: 0.4640 - loss: 1.9469
# Epoch 7: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 226ms/step - categorical_accuracy: 0.4637 - loss: 1.9510 - val_categorical_accuracy: 0.4974 - val_loss: 2.3990
# Epoch 8/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - categorical_accuracy: 0.4556 - loss: 2.0940
# Epoch 8: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 243ms/step - categorical_accuracy: 0.4556 - loss: 2.0919 - val_categorical_accuracy: 0.5105 - val_loss: 1.6362
# Epoch 9/20
# 140/143 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.4358 - loss: 2.4295
# Epoch 9: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 218ms/step - categorical_accuracy: 0.4358 - loss: 2.4317 - val_categorical_accuracy: 0.4773 - val_loss: 2.3227
# Epoch 10/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - categorical_accuracy: 0.4409 - loss: 1.9751
# Epoch 10: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 241ms/step - categorical_accuracy: 0.4410 - loss: 1.9759 - val_categorical_accuracy: 0.4572 - val_loss: 2.1743
# Epoch 11/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - categorical_accuracy: 0.4496 - loss: 2.1098
# Epoch 11: val_categorical_accuracy did not improve from 0.57780
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 46s 309ms/step - categorical_accuracy: 0.4498 - loss: 2.1093 - val_categorical_accuracy: 0.5140 - val_loss: 1.2512
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - categorical_accuracy: 0.4581 - loss: 1.9919
# Epoch 12: val_categorical_accuracy improved from 0.57780 to 0.59703, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 27s 177ms/step - categorical_accuracy: 0.4581 - loss: 1.9927 - val_categorical_accuracy: 0.5970 - val_loss: 1.3808
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - categorical_accuracy: 0.4638 - loss: 2.1840
# Epoch 13: val_categorical_accuracy did not improve from 0.59703
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 218ms/step - categorical_accuracy: 0.4638 - loss: 2.1838 - val_categorical_accuracy: 0.5551 - val_loss: 1.3133
# Epoch 14/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - categorical_accuracy: 0.4691 - loss: 2.0210
# Epoch 14: val_categorical_accuracy did not improve from 0.59703
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 29s 189ms/step - categorical_accuracy: 0.4691 - loss: 2.0203 - val_categorical_accuracy: 0.5079 - val_loss: 2.4872
# Epoch 15/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - categorical_accuracy: 0.4603 - loss: 2.1625
# Epoch 15: val_categorical_accuracy did not improve from 0.59703
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 35s 237ms/step - categorical_accuracy: 0.4603 - loss: 2.1591 - val_categorical_accuracy: 0.4519 - val_loss: 1.5845
# Epoch 16/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - categorical_accuracy: 0.4385 - loss: 2.1738
# Epoch 16: val_categorical_accuracy did not improve from 0.59703
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - categorical_accuracy: 0.4386 - loss: 2.1730 - val_categorical_accuracy: 0.5087 - val_loss: 1.5798
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - categorical_accuracy: 0.4546 - loss: 2.1264
# Epoch 17: val_categorical_accuracy did not improve from 0.59703
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 206ms/step - categorical_accuracy: 0.4546 - loss: 2.1263 - val_categorical_accuracy: 0.5411 - val_loss: 1.8295
# Epoch 18/20
# 136/143 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - categorical_accuracy: 0.4530 - loss: 1.9649
# Epoch 18: val_categorical_accuracy improved from 0.59703 to 0.59965, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 25s 161ms/step - categorical_accuracy: 0.4533 - loss: 1.9646 - val_categorical_accuracy: 0.5997 - val_loss: 1.3003
# Epoch 19/20
# 136/143 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - categorical_accuracy: 0.4859 - loss: 1.9104
# Epoch 19: val_categorical_accuracy did not improve from 0.59965
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 26s 175ms/step - categorical_accuracy: 0.4859 - loss: 1.9082 - val_categorical_accuracy: 0.5551 - val_loss: 1.6611
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - categorical_accuracy: 0.4547 - loss: 1.9913
# Epoch 20: val_categorical_accuracy did not improve from 0.59965
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 28s 182ms/step - categorical_accuracy: 0.4546 - loss: 1.9911 - val_categorical_accuracy: 0.4414 - val_loss: 1.7539

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Predictions</h2>
# </div>

# %%
modelpred1 = load_model('weightsbestTesNet50100%scaled.keras')

modelpred2 = load_model('weightsbestVGG16100%scaled.keras')

modelpred3 = load_model('weightsbestResNet50V2100%scaled.keras')

modelpred4 = load_model('weightsbestENV2B0100%scaled.keras')

modelpred5 = load_model('weightsbestPersonal100%scaled.keras')

# %%
# Obtening Original labels for testing
y_true = np.argmax(y_test,axis=1)

# Labels de TesNet50100
y_pred1 = modelpred1.predict(X_test_scaled)
y_pred1 = np.argmax(y_pred1,axis=1)
# Labels de VGG16100
y_pred2 = modelpred2.predict(X_test_scaled)
y_pred2 = np.argmax(y_pred2,axis=1)
# Labels de ResNet50V2100
y_pred3 = modelpred3.predict(X_test_scaled)
y_pred3 = np.argmax(y_pred3,axis=1)
# Labels de ENV2B0100
y_pred4 = modelpred4.predict(X_test_scaled)
y_pred4 = np.argmax(y_pred4,axis=1)
# Labels de Personal
y_pred5 = modelpred5.predict(X_test_scaled)
y_pred5= np.argmax(y_pred5,axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 91s 2s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 17s 408ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
cnf = confusion_matrix(y_true, y_pred1)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('TesNet50')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred2)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('VGG16100')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred3)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('ResNet50')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred4)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('ENV2B0100')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred5)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('Personalized')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)

# %%
print('TesNet50' + classification_report(y_true, y_pred1))
print('-------------------------------------------------------------------------')
print('VGG16100' + classification_report(y_true, y_pred2))
print('-------------------------------------------------------------------------')
print('ResNet50' + classification_report(y_true, y_pred3))
print('-------------------------------------------------------------------------')
print('ENV2B' + classification_report(y_true, y_pred4))
print('-------------------------------------------------------------------------')
print('Personalized' + classification_report(y_true, y_pred5))
print('--------------------------------------------------')
# Out:
# TesNet50              precision    recall  f1-score   support
#
#            0       0.82      0.66      0.73       300
#            1       0.94      0.92      0.93       405
#            2       0.66      0.77      0.71       306
#            3       0.88      0.93      0.90       300
#
#     accuracy                           0.83      1311
#    macro avg       0.82      0.82      0.82      1311
# weighted avg       0.83      0.83      0.83      1311
#
# -------------------------------------------------------------------------
# VGG16100              precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91       300
#            1       0.96      0.99      0.98       405
#            2       0.85      0.91      0.88       306
#            3       0.95      0.97      0.96       300
#
#     accuracy                           0.94      1311
#    macro avg       0.94      0.93      0.93      1311
# weighted avg       0.94      0.94      0.94      1311
#
# -------------------------------------------------------------------------
# ResNet50              precision    recall  f1-score   support
#
#            0       0.97      0.83      0.90       300
#            1       0.98      0.99      0.98       405
#            2       0.83      0.93      0.87       306
#            3       0.96      0.96      0.96       300
#
#     accuracy                           0.93      1311
#    macro avg       0.93      0.93      0.93      1311
# weighted avg       0.94      0.93      0.93      1311
#
# -------------------------------------------------------------------------
# ENV2B              precision    recall  f1-score   support
#
#            0       0.99      0.87      0.93       300
#            1       0.97      0.99      0.98       405
#            2       0.89      0.90      0.90       306
#            3       0.92      1.00      0.96       300
#
#     accuracy                           0.94      1311
#    macro avg       0.94      0.94      0.94      1311
# weighted avg       0.95      0.94      0.94      1311
#
# -------------------------------------------------------------------------
# Personal              precision    recall  f1-score   support
#
#            0       0.48      0.61      0.54       300
#            1       0.83      0.58      0.68       405
#            2       0.36      0.18      0.24       306
#            3       0.52      0.86      0.65       300
#
#     accuracy                           0.56      1311
#    macro avg       0.55      0.56      0.53      1311
# weighted avg       0.57      0.56      0.54      1311
#
# --------------------------------------------------

# %%
# Columnas de la tabla
t = PrettyTable(['Model', 'Accuracy', 'glioma','meningioma', 'notumor', 'pituitary'])
# To insert rows:
t.add_row(['TesNet50', 0.83,0.82,0.94,0.66,0.88])
t.add_row(['VGG16100', 0.94,0.97,0.96,0.85,0.95 ])
t.add_row(['ResNet50', 0.94,0.97,0.98,0.83,0.96])
t.add_row(['ENV2B', 0.95,0.99,0.97,0.89,0.92])
t.add_row(['Personalized', 0.57,0.48,0.83,0.36,0.52 ])
print(t)
# Out:
# +--------------+----------+--------+------------+---------+-----------+
# |    Model     | Accuracy | glioma | meningioma | notumor | pituitary |
# +--------------+----------+--------+------------+---------+-----------+
# |   TesNet50   |   0.83   |  0.82  |    0.94    |   0.66  |    0.88   |
# |   VGG16100   |   0.94   |  0.97  |    0.96    |   0.85  |    0.95   |
# |   ResNet50   |   0.94   |  0.97  |    0.98    |   0.83  |    0.96   |
# |    ENV2B     |   0.95   |  0.99  |    0.97    |   0.89  |    0.92   |
# | Personalized |   0.57   |  0.48  |    0.83    |   0.36  |    0.52   |
# +--------------+----------+--------+------------+---------+-----------+

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Data Import and split 70-30</h2>
# </div>

# %%
TRAIN_DIR = r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\StrategicThinkingCA3-\\MedicalImages\\Training'
splitfolders.ratio(TRAIN_DIR, output="DataSplit", ratio=(0.7, 0.3))
# Out:
# Copying files: 5712 files [00:32, 178.40 files/s]

# %%
X_train = []
y_train = []
image_size = 150
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\','x_train87%',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size, image_size))
        X_train.append(img)
        y_train.append(i)
  
 
    
X_val = []
y_val = []
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\DataSplit\\','y_train30%',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_val.append(img)
        y_val.append(i)
        

X_test = []
y_test = []
        
for i in labels:
    folderPath = os.path.join(r'C:\\Users\\eduma\\OneDrive\\Escritorio\\CA3\\StrategicThinkingCA3-\\MedicalImages\\','Testing',i)
    for j in tqdm(os.listdir(folderPath)):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_test.append(img)
        y_test.append(i)
        
X_train = np.array(X_train)
y_train = np.array(y_train)
X_val = np.array(X_val)
y_val = np.array(y_val)
X_test = np.array(X_test)
y_test = np.array(y_test)
# Out:
# 100%|██████████| 1056/1056 [00:05<00:00, 197.12it/s]
# 100%|██████████| 1276/1276 [00:06<00:00, 187.59it/s]
# 100%|██████████| 1071/1071 [00:05<00:00, 201.24it/s]
# 100%|██████████| 1165/1165 [00:09<00:00, 128.24it/s]
# 100%|██████████| 265/265 [00:01<00:00, 146.24it/s]
# 100%|██████████| 319/319 [00:02<00:00, 157.47it/s]
# 100%|██████████| 268/268 [00:01<00:00, 140.01it/s]
# 100%|██████████| 292/292 [00:01<00:00, 155.34it/s]
# 100%|██████████| 300/300 [00:01<00:00, 185.81it/s]
# 100%|██████████| 405/405 [00:01<00:00, 239.27it/s]
# 100%|██████████| 306/306 [00:01<00:00, 202.32it/s]
# 100%|██████████| 300/300 [00:01<00:00, 192.53it/s]

# %%
print('Training 70%')
print(X_train.shape)
print('Training 30%')
print(X_val.shape)
print('Test')
print(X_test.shape)
# Out:
# Training 70%
# (4568, 150, 150, 3)
# Training 30%
# (1144, 150, 150, 3)
# Test
# (1311, 150, 150, 3)

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">One-Hot Encoding</h2>
# </div>

# %%
y_train_new = []
for i in y_train:
 y_train_new.append(labels.index(i))

y_train = tf.keras.utils.to_categorical(y_train_new)
y_val_new = []
for i in y_val:
 y_val_new.append(labels.index(i))
y_val = tf.keras.utils.to_categorical(y_val_new)
y_test_new = []
for i in y_test:
 y_test_new.append(labels.index(i))
y_test = tf.keras.utils.to_categorical(y_test_new)

# %%
# Scaling Train, Valid and Test Features
X_train_scaled = X_train.astype('float32')
X_val_scaled = X_val.astype('float32')
X_test_scaled = X_test.astype('float32')
X_train_scaled /= 255.
X_val_scaled /= 255.
X_test_scaled /= 255.

# %%
minvalue = np.min(X_train)
maxvalue = np.max(X_train)
minvalues = np.min(X_train_scaled)
maxvalues = np.max(X_train_scaled)
print(minvalue)
print(maxvalue)
print(minvalues)
print(maxvalues)
# Out:
# 0
# 255
# 0.0
# 1.0

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ResNet50</h2>
# </div>

# %%
# Loading the pre-trained ResNet50 model without the top classification layer
res_model = ResNet50(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)

# Freezing the layers of the pre-trained model
for layer in res_model.layers:
    layer.trainable = False

# Building the new model
model = Sequential()
model.add(res_model)
model.add(Flatten())
model.add(Dense(4, activation='softmax'))  # 4 classes in the output layer

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# %%
# Defining the checkpoint
filepath = "weightsbestTesNet50100%scaled.keras"  # Updated extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
historyres = model.fit(datagen.flow(X_train_scaled, y_train, batch_size=32),
validation_data=(X_val_scaled, y_val),
batch_size=32,
epochs=20,
callbacks=callbacks_list)
# Out:
# Epoch 1/20
# c:\Users\eduma\OneDrive\Escritorio\CA3\test\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.4588 - loss: 1.3034
# Epoch 1: val_categorical_accuracy improved from -inf to 0.64336, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 359s 2s/step - categorical_accuracy: 0.4594 - loss: 1.3018 - val_categorical_accuracy: 0.6434 - val_loss: 0.9086
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6326 - loss: 0.9162
# Epoch 2: val_categorical_accuracy improved from 0.64336 to 0.74388, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 272s 2s/step - categorical_accuracy: 0.6327 - loss: 0.9158 - val_categorical_accuracy: 0.7439 - val_loss: 0.7007
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6644 - loss: 0.8393
# Epoch 3: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - categorical_accuracy: 0.6644 - loss: 0.8393 - val_categorical_accuracy: 0.7290 - val_loss: 0.6635
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6550 - loss: 0.8198
# Epoch 4: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - categorical_accuracy: 0.6548 - loss: 0.8203 - val_categorical_accuracy: 0.6949 - val_loss: 0.8948
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6686 - loss: 0.7900
# Epoch 5: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - categorical_accuracy: 0.6687 - loss: 0.7898 - val_categorical_accuracy: 0.7247 - val_loss: 0.6916
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6834 - loss: 0.7630
# Epoch 6: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 310s 2s/step - categorical_accuracy: 0.6834 - loss: 0.7630 - val_categorical_accuracy: 0.7386 - val_loss: 0.7811
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7136 - loss: 0.7024
# Epoch 7: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 318s 2s/step - categorical_accuracy: 0.7136 - loss: 0.7024 - val_categorical_accuracy: 0.7150 - val_loss: 0.7187
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7226 - loss: 0.6894
# Epoch 8: val_categorical_accuracy did not improve from 0.74388
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - categorical_accuracy: 0.7225 - loss: 0.6895 - val_categorical_accuracy: 0.7308 - val_loss: 0.7265
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7109 - loss: 0.7313
# Epoch 9: val_categorical_accuracy improved from 0.74388 to 0.76661, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - categorical_accuracy: 0.7110 - loss: 0.7311 - val_categorical_accuracy: 0.7666 - val_loss: 0.6342
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7337 - loss: 0.6498
# Epoch 10: val_categorical_accuracy improved from 0.76661 to 0.77185, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - categorical_accuracy: 0.7337 - loss: 0.6499 - val_categorical_accuracy: 0.7719 - val_loss: 0.5906
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7166 - loss: 0.6855
# Epoch 11: val_categorical_accuracy improved from 0.77185 to 0.77972, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - categorical_accuracy: 0.7165 - loss: 0.6856 - val_categorical_accuracy: 0.7797 - val_loss: 0.5841
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.6945 - loss: 0.7467
# Epoch 12: val_categorical_accuracy did not improve from 0.77972
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 267s 2s/step - categorical_accuracy: 0.6946 - loss: 0.7464 - val_categorical_accuracy: 0.7622 - val_loss: 0.6165
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7275 - loss: 0.6639
# Epoch 13: val_categorical_accuracy did not improve from 0.77972
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - categorical_accuracy: 0.7275 - loss: 0.6639 - val_categorical_accuracy: 0.7710 - val_loss: 0.5838
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7408 - loss: 0.6405
# Epoch 14: val_categorical_accuracy did not improve from 0.77972
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - categorical_accuracy: 0.7407 - loss: 0.6408 - val_categorical_accuracy: 0.7526 - val_loss: 0.6353
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7295 - loss: 0.6505
# Epoch 15: val_categorical_accuracy improved from 0.77972 to 0.78322, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 265s 2s/step - categorical_accuracy: 0.7295 - loss: 0.6505 - val_categorical_accuracy: 0.7832 - val_loss: 0.6085
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7423 - loss: 0.6438
# Epoch 16: val_categorical_accuracy did not improve from 0.78322
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - categorical_accuracy: 0.7423 - loss: 0.6438 - val_categorical_accuracy: 0.7780 - val_loss: 0.5775
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7530 - loss: 0.6174
# Epoch 17: val_categorical_accuracy did not improve from 0.78322
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - categorical_accuracy: 0.7530 - loss: 0.6175 - val_categorical_accuracy: 0.7325 - val_loss: 0.7528
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7401 - loss: 0.6399
# Epoch 18: val_categorical_accuracy did not improve from 0.78322
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - categorical_accuracy: 0.7401 - loss: 0.6397 - val_categorical_accuracy: 0.6827 - val_loss: 0.9229
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7370 - loss: 0.6628
# Epoch 19: val_categorical_accuracy improved from 0.78322 to 0.79458, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 268s 2s/step - categorical_accuracy: 0.7371 - loss: 0.6626 - val_categorical_accuracy: 0.7946 - val_loss: 0.5481
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7343 - loss: 0.6499
# Epoch 20: val_categorical_accuracy improved from 0.79458 to 0.80769, saving model to weightsbestTesNet50100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - categorical_accuracy: 0.7343 - loss: 0.6501 - val_categorical_accuracy: 0.8077 - val_loss: 0.5288

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">VGG16</h2>
# </div>

# %%
# Loading the pre-trained VGG16 model without the top classification layer
v = VGG16(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)

# Freezing the layers of the pre-trained model
for layer in v.layers:
    layer.trainable = False

# Building the new model
model = Sequential()
model.add(v)
model.add(Flatten())
model.add(Dense(4, activation='softmax'))  # 4 classes in the output layer

# Compiling the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Defining the checkpoint
filepath = "weightsbestVGG16100%scaled.keras"  # Updated extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)

# Fitting the model
historyVGG16 = model.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6656 - loss: 0.8326
# Epoch 1: val_categorical_accuracy improved from -inf to 0.85664, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 426s 3s/step - categorical_accuracy: 0.6663 - loss: 0.8310 - val_categorical_accuracy: 0.8566 - val_loss: 0.3841
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8558 - loss: 0.3961
# Epoch 2: val_categorical_accuracy improved from 0.85664 to 0.87762, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 415s 3s/step - categorical_accuracy: 0.8558 - loss: 0.3960 - val_categorical_accuracy: 0.8776 - val_loss: 0.3764
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8737 - loss: 0.3437
# Epoch 3: val_categorical_accuracy did not improve from 0.87762
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 411s 3s/step - categorical_accuracy: 0.8737 - loss: 0.3436 - val_categorical_accuracy: 0.8776 - val_loss: 0.3460
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9001 - loss: 0.2786
# Epoch 4: val_categorical_accuracy did not improve from 0.87762
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 414s 3s/step - categorical_accuracy: 0.9001 - loss: 0.2787 - val_categorical_accuracy: 0.8750 - val_loss: 0.3592
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8909 - loss: 0.2766
# Epoch 5: val_categorical_accuracy improved from 0.87762 to 0.90385, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 415s 3s/step - categorical_accuracy: 0.8910 - loss: 0.2765 - val_categorical_accuracy: 0.9038 - val_loss: 0.2804
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9108 - loss: 0.2420
# Epoch 6: val_categorical_accuracy did not improve from 0.90385
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 405s 3s/step - categorical_accuracy: 0.9108 - loss: 0.2421 - val_categorical_accuracy: 0.9003 - val_loss: 0.2729
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9087 - loss: 0.2390
# Epoch 7: val_categorical_accuracy improved from 0.90385 to 0.90909, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 420s 3s/step - categorical_accuracy: 0.9088 - loss: 0.2390 - val_categorical_accuracy: 0.9091 - val_loss: 0.2440
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9197 - loss: 0.2281
# Epoch 8: val_categorical_accuracy improved from 0.90909 to 0.91696, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 408s 3s/step - categorical_accuracy: 0.9197 - loss: 0.2281 - val_categorical_accuracy: 0.9170 - val_loss: 0.2340
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9328 - loss: 0.2058
# Epoch 9: val_categorical_accuracy did not improve from 0.91696
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 410s 3s/step - categorical_accuracy: 0.9327 - loss: 0.2059 - val_categorical_accuracy: 0.8776 - val_loss: 0.3072
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9170 - loss: 0.2236
# Epoch 10: val_categorical_accuracy did not improve from 0.91696
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 414s 3s/step - categorical_accuracy: 0.9170 - loss: 0.2235 - val_categorical_accuracy: 0.8951 - val_loss: 0.3210
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9205 - loss: 0.2056
# Epoch 11: val_categorical_accuracy did not improve from 0.91696
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 408s 3s/step - categorical_accuracy: 0.9206 - loss: 0.2055 - val_categorical_accuracy: 0.9161 - val_loss: 0.2327
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9270 - loss: 0.1925
# Epoch 12: val_categorical_accuracy improved from 0.91696 to 0.92395, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 409s 3s/step - categorical_accuracy: 0.9271 - loss: 0.1925 - val_categorical_accuracy: 0.9240 - val_loss: 0.2249
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9266 - loss: 0.1893
# Epoch 13: val_categorical_accuracy did not improve from 0.92395
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 416s 3s/step - categorical_accuracy: 0.9266 - loss: 0.1893 - val_categorical_accuracy: 0.9231 - val_loss: 0.2231
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9328 - loss: 0.1779
# Epoch 14: val_categorical_accuracy improved from 0.92395 to 0.92570, saving model to weightsbestVGG16100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 401s 3s/step - categorical_accuracy: 0.9328 - loss: 0.1780 - val_categorical_accuracy: 0.9257 - val_loss: 0.2179
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9446 - loss: 0.1691
# Epoch 15: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 407s 3s/step - categorical_accuracy: 0.9446 - loss: 0.1691 - val_categorical_accuracy: 0.9231 - val_loss: 0.2249
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9381 - loss: 0.1681
# Epoch 16: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 407s 3s/step - categorical_accuracy: 0.9381 - loss: 0.1682 - val_categorical_accuracy: 0.9213 - val_loss: 0.2227
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9325 - loss: 0.1805
# Epoch 17: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 394s 3s/step - categorical_accuracy: 0.9325 - loss: 0.1805 - val_categorical_accuracy: 0.9117 - val_loss: 0.2500
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9437 - loss: 0.1593
# Epoch 18: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 407s 3s/step - categorical_accuracy: 0.9437 - loss: 0.1593 - val_categorical_accuracy: 0.9248 - val_loss: 0.2147
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9463 - loss: 0.1597
# Epoch 19: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 405s 3s/step - categorical_accuracy: 0.9463 - loss: 0.1597 - val_categorical_accuracy: 0.9073 - val_loss: 0.2678
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9545 - loss: 0.1447
# Epoch 20: val_categorical_accuracy did not improve from 0.92570
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 398s 3s/step - categorical_accuracy: 0.9545 - loss: 0.1448 - val_categorical_accuracy: 0.9187 - val_loss: 0.2458

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ResNet50 V2</h2>
# </div>

# %%
rsv2 = ResNet50V2(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False)
for layer in rsv2.layers:
    layer.trainable = False

modelrsv2 = Sequential()
modelrsv2.add(rsv2)
modelrsv2.add(Flatten())
modelrsv2.add(Dense(4, activation='softmax'))

modelrsv2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# checkpoint
filepath = "weightsbestResNet50V2100%scaled.keras"
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

historyrsv2 = modelrsv2.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.7015 - loss: 2.9665
# Epoch 1: val_categorical_accuracy improved from -inf to 0.85052, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - categorical_accuracy: 0.7022 - loss: 2.9600 - val_categorical_accuracy: 0.8505 - val_loss: 1.3547
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8529 - loss: 1.2519
# Epoch 2: val_categorical_accuracy improved from 0.85052 to 0.89073, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - categorical_accuracy: 0.8530 - loss: 1.2522 - val_categorical_accuracy: 0.8907 - val_loss: 1.4732
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8806 - loss: 1.1351
# Epoch 3: val_categorical_accuracy did not improve from 0.89073
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - categorical_accuracy: 0.8806 - loss: 1.1357 - val_categorical_accuracy: 0.8802 - val_loss: 1.9532
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.8983 - loss: 1.0923
# Epoch 4: val_categorical_accuracy did not improve from 0.89073
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - categorical_accuracy: 0.8983 - loss: 1.0925 - val_categorical_accuracy: 0.8767 - val_loss: 1.4600
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9027 - loss: 0.9925
# Epoch 5: val_categorical_accuracy improved from 0.89073 to 0.89598, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - categorical_accuracy: 0.9027 - loss: 0.9928 - val_categorical_accuracy: 0.8960 - val_loss: 1.5112
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9086 - loss: 1.2290
# Epoch 6: val_categorical_accuracy improved from 0.89598 to 0.90297, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - categorical_accuracy: 0.9087 - loss: 1.2282 - val_categorical_accuracy: 0.9030 - val_loss: 1.4292
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9266 - loss: 0.8503
# Epoch 7: val_categorical_accuracy improved from 0.90297 to 0.91871, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 231s 2s/step - categorical_accuracy: 0.9265 - loss: 0.8513 - val_categorical_accuracy: 0.9187 - val_loss: 1.0922
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9150 - loss: 1.1564
# Epoch 8: val_categorical_accuracy did not improve from 0.91871
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 227s 2s/step - categorical_accuracy: 0.9150 - loss: 1.1558 - val_categorical_accuracy: 0.9021 - val_loss: 1.5632
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9368 - loss: 0.6906
# Epoch 9: val_categorical_accuracy did not improve from 0.91871
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - categorical_accuracy: 0.9368 - loss: 0.6913 - val_categorical_accuracy: 0.9065 - val_loss: 1.2513
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9258 - loss: 1.0343
# Epoch 10: val_categorical_accuracy did not improve from 0.91871
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - categorical_accuracy: 0.9258 - loss: 1.0341 - val_categorical_accuracy: 0.9056 - val_loss: 1.5990
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9392 - loss: 0.8153
# Epoch 11: val_categorical_accuracy did not improve from 0.91871
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - categorical_accuracy: 0.9391 - loss: 0.8156 - val_categorical_accuracy: 0.9030 - val_loss: 1.8047
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9316 - loss: 0.9429
# Epoch 12: val_categorical_accuracy improved from 0.91871 to 0.92657, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - categorical_accuracy: 0.9316 - loss: 0.9426 - val_categorical_accuracy: 0.9266 - val_loss: 1.1686
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9343 - loss: 0.9096
# Epoch 13: val_categorical_accuracy improved from 0.92657 to 0.93182, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - categorical_accuracy: 0.9344 - loss: 0.9094 - val_categorical_accuracy: 0.9318 - val_loss: 1.0239
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9469 - loss: 0.6552
# Epoch 14: val_categorical_accuracy did not improve from 0.93182
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - categorical_accuracy: 0.9468 - loss: 0.6562 - val_categorical_accuracy: 0.9178 - val_loss: 1.2391
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9252 - loss: 1.1952
# Epoch 15: val_categorical_accuracy did not improve from 0.93182
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - categorical_accuracy: 0.9252 - loss: 1.1948 - val_categorical_accuracy: 0.8855 - val_loss: 2.1931
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9418 - loss: 0.8164
# Epoch 16: val_categorical_accuracy did not improve from 0.93182
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - categorical_accuracy: 0.9418 - loss: 0.8167 - val_categorical_accuracy: 0.9056 - val_loss: 1.7842
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9478 - loss: 0.7433
# Epoch 17: val_categorical_accuracy improved from 0.93182 to 0.93269, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 229s 2s/step - categorical_accuracy: 0.9478 - loss: 0.7437 - val_categorical_accuracy: 0.9327 - val_loss: 1.4172
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9469 - loss: 0.7225
# Epoch 18: val_categorical_accuracy did not improve from 0.93269
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - categorical_accuracy: 0.9468 - loss: 0.7234 - val_categorical_accuracy: 0.9301 - val_loss: 1.4490
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9547 - loss: 0.7137
# Epoch 19: val_categorical_accuracy improved from 0.93269 to 0.93357, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - categorical_accuracy: 0.9547 - loss: 0.7146 - val_categorical_accuracy: 0.9336 - val_loss: 1.2453
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - categorical_accuracy: 0.9471 - loss: 0.9130
# Epoch 20: val_categorical_accuracy improved from 0.93357 to 0.94580, saving model to weightsbestResNet50V2100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 230s 2s/step - categorical_accuracy: 0.9471 - loss: 0.9125 - val_categorical_accuracy: 0.9458 - val_loss: 1.0629

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">ENV2B0</h2>
# </div>

# %%
# DefinING the model
env2b0 = EfficientNetV2B0(weights='imagenet', input_shape=(image_size, image_size, 3), include_top=False, include_preprocessing=False)
for layer in env2b0.layers:
    layer.trainable = False

modelenv2b0 = Sequential()
modelenv2b0.add(env2b0)
modelenv2b0.add(Flatten())
modelenv2b0.add(Dense(4, activation='softmax'))

modelenv2b0.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Checkpoint
filepath = "weightsbestENV2B0100%scaled.keras"  # .keras extension
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Fitting the model
historyenv2b0 = modelenv2b0.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# Epoch 1/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - categorical_accuracy: 0.7217 - loss: 1.0732
# Epoch 1: val_categorical_accuracy improved from -inf to 0.84878, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 147s 800ms/step - categorical_accuracy: 0.7222 - loss: 1.0712 - val_categorical_accuracy: 0.8488 - val_loss: 0.5504
# Epoch 2/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - categorical_accuracy: 0.8377 - loss: 0.5835
# Epoch 2: val_categorical_accuracy improved from 0.84878 to 0.87675, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 98s 676ms/step - categorical_accuracy: 0.8379 - loss: 0.5831 - val_categorical_accuracy: 0.8767 - val_loss: 0.4608
# Epoch 3/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - categorical_accuracy: 0.8767 - loss: 0.4246
# Epoch 3: val_categorical_accuracy did not improve from 0.87675
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 100s 688ms/step - categorical_accuracy: 0.8767 - loss: 0.4248 - val_categorical_accuracy: 0.8759 - val_loss: 0.6205
# Epoch 4/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - categorical_accuracy: 0.9006 - loss: 0.4166
# Epoch 4: val_categorical_accuracy improved from 0.87675 to 0.90472, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 98s 675ms/step - categorical_accuracy: 0.9006 - loss: 0.4163 - val_categorical_accuracy: 0.9047 - val_loss: 0.4600
# Epoch 5/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 595ms/step - categorical_accuracy: 0.9064 - loss: 0.3446
# Epoch 5: val_categorical_accuracy improved from 0.90472 to 0.92920, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 104s 717ms/step - categorical_accuracy: 0.9063 - loss: 0.3451 - val_categorical_accuracy: 0.9292 - val_loss: 0.2929
# Epoch 6/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - categorical_accuracy: 0.8954 - loss: 0.4680
# Epoch 6: val_categorical_accuracy did not improve from 0.92920
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 101s 692ms/step - categorical_accuracy: 0.8954 - loss: 0.4680 - val_categorical_accuracy: 0.8724 - val_loss: 0.6896
# Epoch 7/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - categorical_accuracy: 0.9113 - loss: 0.3592
# Epoch 7: val_categorical_accuracy did not improve from 0.92920
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 99s 681ms/step - categorical_accuracy: 0.9113 - loss: 0.3594 - val_categorical_accuracy: 0.8846 - val_loss: 0.7134
# Epoch 8/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - categorical_accuracy: 0.9145 - loss: 0.3433
# Epoch 8: val_categorical_accuracy did not improve from 0.92920
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 101s 694ms/step - categorical_accuracy: 0.9145 - loss: 0.3433 - val_categorical_accuracy: 0.9196 - val_loss: 0.4393
# Epoch 9/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - categorical_accuracy: 0.9121 - loss: 0.3562
# Epoch 9: val_categorical_accuracy improved from 0.92920 to 0.93182, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 98s 675ms/step - categorical_accuracy: 0.9121 - loss: 0.3561 - val_categorical_accuracy: 0.9318 - val_loss: 0.3205
# Epoch 10/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - categorical_accuracy: 0.9248 - loss: 0.3098
# Epoch 10: val_categorical_accuracy improved from 0.93182 to 0.93881, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 99s 680ms/step - categorical_accuracy: 0.9248 - loss: 0.3099 - val_categorical_accuracy: 0.9388 - val_loss: 0.3896
# Epoch 11/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - categorical_accuracy: 0.9143 - loss: 0.3854
# Epoch 11: val_categorical_accuracy did not improve from 0.93881
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 100s 683ms/step - categorical_accuracy: 0.9143 - loss: 0.3854 - val_categorical_accuracy: 0.9327 - val_loss: 0.4791
# Epoch 12/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - categorical_accuracy: 0.9355 - loss: 0.2817
# Epoch 12: val_categorical_accuracy did not improve from 0.93881
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 100s 691ms/step - categorical_accuracy: 0.9354 - loss: 0.2819 - val_categorical_accuracy: 0.8934 - val_loss: 0.6387
# Epoch 13/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - categorical_accuracy: 0.9240 - loss: 0.3240
# Epoch 13: val_categorical_accuracy improved from 0.93881 to 0.94143, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 100s 685ms/step - categorical_accuracy: 0.9240 - loss: 0.3240 - val_categorical_accuracy: 0.9414 - val_loss: 0.2780
# Epoch 14/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - categorical_accuracy: 0.9284 - loss: 0.3314
# Epoch 14: val_categorical_accuracy improved from 0.94143 to 0.94231, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 100s 689ms/step - categorical_accuracy: 0.9285 - loss: 0.3311 - val_categorical_accuracy: 0.9423 - val_loss: 0.3895
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - categorical_accuracy: 0.9278 - loss: 0.3368
# Epoch 15: val_categorical_accuracy did not improve from 0.94231
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 103s 707ms/step - categorical_accuracy: 0.9278 - loss: 0.3371 - val_categorical_accuracy: 0.9283 - val_loss: 0.4278
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - categorical_accuracy: 0.9370 - loss: 0.3057
# Epoch 16: val_categorical_accuracy did not improve from 0.94231
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 97s 669ms/step - categorical_accuracy: 0.9370 - loss: 0.3059 - val_categorical_accuracy: 0.9257 - val_loss: 0.4109
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - categorical_accuracy: 0.9283 - loss: 0.3422
# Epoch 17: val_categorical_accuracy did not improve from 0.94231
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 99s 678ms/step - categorical_accuracy: 0.9284 - loss: 0.3422 - val_categorical_accuracy: 0.9222 - val_loss: 0.5272
# Epoch 18/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - categorical_accuracy: 0.9460 - loss: 0.2472
# Epoch 18: val_categorical_accuracy did not improve from 0.94231
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 98s 678ms/step - categorical_accuracy: 0.9460 - loss: 0.2472 - val_categorical_accuracy: 0.9388 - val_loss: 0.4004
# Epoch 19/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - categorical_accuracy: 0.9538 - loss: 0.2104
# Epoch 19: val_categorical_accuracy did not improve from 0.94231
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 99s 683ms/step - categorical_accuracy: 0.9537 - loss: 0.2108 - val_categorical_accuracy: 0.9283 - val_loss: 0.5195
# Epoch 20/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - categorical_accuracy: 0.9404 - loss: 0.2930
# Epoch 20: val_categorical_accuracy improved from 0.94231 to 0.94580, saving model to weightsbestENV2B0100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 99s 685ms/step - categorical_accuracy: 0.9404 - loss: 0.2930 - val_categorical_accuracy: 0.9458 - val_loss: 0.3603

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Personalized</h2>
# </div>

# %%
modelP = Sequential()
modelP.add(Flatten(input_shape=(image_size, image_size, 3)))
modelP.add(Dense(4, activation='softmax'))

modelP.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])

# Define the name of the file for saving the models
filepath = "weightsbestPersonal100%scaled.keras"  # Changed to .keras extension

# Set up ModelCheckpoint
checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# Train the model
historyPers = modelP.fit(
    datagen.flow(X_train_scaled, y_train, batch_size=32),
    validation_data=(X_val_scaled, y_val),
    batch_size=32,
    epochs=20,
    callbacks=callbacks_list
)
# Out:
# c:\Users\eduma\OneDrive\Escritorio\CA3\test\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 140/143 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - categorical_accuracy: 0.3732 - loss: 3.6187
# Epoch 1: val_categorical_accuracy improved from -inf to 0.49913, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 37s 232ms/step - categorical_accuracy: 0.3739 - loss: 3.5874 - val_categorical_accuracy: 0.4991 - val_loss: 1.2600
# Epoch 2/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - categorical_accuracy: 0.4396 - loss: 1.8721
# Epoch 2: val_categorical_accuracy improved from 0.49913 to 0.56556, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 239ms/step - categorical_accuracy: 0.4396 - loss: 1.8746 - val_categorical_accuracy: 0.5656 - val_loss: 1.2409
# Epoch 3/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - categorical_accuracy: 0.4400 - loss: 1.7620
# Epoch 3: val_categorical_accuracy improved from 0.56556 to 0.56993, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - categorical_accuracy: 0.4400 - loss: 1.7628 - val_categorical_accuracy: 0.5699 - val_loss: 1.2930
# Epoch 4/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - categorical_accuracy: 0.4409 - loss: 2.2747
# Epoch 4: val_categorical_accuracy did not improve from 0.56993
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 208ms/step - categorical_accuracy: 0.4409 - loss: 2.2741 - val_categorical_accuracy: 0.5087 - val_loss: 1.7244
# Epoch 5/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - categorical_accuracy: 0.4552 - loss: 1.6845
# Epoch 5: val_categorical_accuracy did not improve from 0.56993
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - categorical_accuracy: 0.4552 - loss: 1.6854 - val_categorical_accuracy: 0.4843 - val_loss: 1.8138
# Epoch 6/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - categorical_accuracy: 0.4269 - loss: 2.5044
# Epoch 6: val_categorical_accuracy did not improve from 0.56993
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 35s 231ms/step - categorical_accuracy: 0.4271 - loss: 2.4998 - val_categorical_accuracy: 0.5210 - val_loss: 1.4293
# Epoch 7/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - categorical_accuracy: 0.4641 - loss: 1.9524
# Epoch 7: val_categorical_accuracy did not improve from 0.56993
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 227ms/step - categorical_accuracy: 0.4639 - loss: 1.9544 - val_categorical_accuracy: 0.5551 - val_loss: 2.3661
# Epoch 8/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - categorical_accuracy: 0.4175 - loss: 2.3764
# Epoch 8: val_categorical_accuracy improved from 0.56993 to 0.59003, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 221ms/step - categorical_accuracy: 0.4178 - loss: 2.3737 - val_categorical_accuracy: 0.5900 - val_loss: 1.3821
# Epoch 9/20
# 140/143 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - categorical_accuracy: 0.4511 - loss: 2.2389
# Epoch 9: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 207ms/step - categorical_accuracy: 0.4509 - loss: 2.2388 - val_categorical_accuracy: 0.4773 - val_loss: 1.8415
# Epoch 10/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - categorical_accuracy: 0.4576 - loss: 2.0941
# Epoch 10: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 217ms/step - categorical_accuracy: 0.4575 - loss: 2.0954 - val_categorical_accuracy: 0.5717 - val_loss: 1.4108
# Epoch 11/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.4750 - loss: 2.0183
# Epoch 11: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 224ms/step - categorical_accuracy: 0.4748 - loss: 2.0203 - val_categorical_accuracy: 0.4371 - val_loss: 1.7846
# Epoch 12/20
# 136/143 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - categorical_accuracy: 0.4348 - loss: 2.3150
# Epoch 12: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 224ms/step - categorical_accuracy: 0.4357 - loss: 2.3133 - val_categorical_accuracy: 0.5000 - val_loss: 1.8383
# Epoch 13/20
# 141/143 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.4657 - loss: 2.3028
# Epoch 13: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 223ms/step - categorical_accuracy: 0.4658 - loss: 2.3003 - val_categorical_accuracy: 0.5516 - val_loss: 1.9081
# Epoch 14/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.4725 - loss: 2.0981
# Epoch 14: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 223ms/step - categorical_accuracy: 0.4724 - loss: 2.0973 - val_categorical_accuracy: 0.4432 - val_loss: 1.8976
# Epoch 15/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - categorical_accuracy: 0.4778 - loss: 1.8855
# Epoch 15: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 212ms/step - categorical_accuracy: 0.4778 - loss: 1.8855 - val_categorical_accuracy: 0.5691 - val_loss: 1.4484
# Epoch 16/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - categorical_accuracy: 0.4643 - loss: 1.8545
# Epoch 16: val_categorical_accuracy did not improve from 0.59003
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 214ms/step - categorical_accuracy: 0.4643 - loss: 1.8553 - val_categorical_accuracy: 0.5830 - val_loss: 1.4486
# Epoch 17/20
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - categorical_accuracy: 0.4577 - loss: 2.0883
# Epoch 17: val_categorical_accuracy improved from 0.59003 to 0.59790, saving model to weightsbestPersonal100%scaled.keras
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 228ms/step - categorical_accuracy: 0.4576 - loss: 2.0888 - val_categorical_accuracy: 0.5979 - val_loss: 1.1939
# Epoch 18/20
# 140/143 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - categorical_accuracy: 0.4379 - loss: 2.2329
# Epoch 18: val_categorical_accuracy did not improve from 0.59790
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 215ms/step - categorical_accuracy: 0.4382 - loss: 2.2358 - val_categorical_accuracy: 0.4948 - val_loss: 1.7480
# Epoch 19/20
# 142/143 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.4862 - loss: 1.9868
# Epoch 19: val_categorical_accuracy did not improve from 0.59790
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 223ms/step - categorical_accuracy: 0.4860 - loss: 1.9889 - val_categorical_accuracy: 0.3138 - val_loss: 3.5112
# Epoch 20/20
# 140/143 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - categorical_accuracy: 0.4664 - loss: 2.4428
# Epoch 20: val_categorical_accuracy did not improve from 0.59790
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 209ms/step - categorical_accuracy: 0.4666 - loss: 2.4334 - val_categorical_accuracy: 0.5542 - val_loss: 1.5474

# %% [markdown]
# <div style="background-color: #60DBD8; color: black; text-align: center; padding: 10px; border-radius: 20px; margin-top: 20px; margin-bottom: 20px;">
#   <h2 style="margin: 0;">Predictions</h2>
# </div>

# %%
modelpred1 = load_model('weightsbestTesNet50100%scaled.keras')

modelpred2 = load_model('weightsbestVGG16100%scaled.keras')

modelpred3 = load_model('weightsbestResNet50V2100%scaled.keras')

modelpred4 = load_model('weightsbestENV2B0100%scaled.keras')

modelpred5 = load_model('weightsbestPersonal100%scaled.keras')

# %%
# Obtening Original labels for testing
y_true = np.argmax(y_test,axis=1)

# Labels de TesNet50100
y_pred1 = modelpred1.predict(X_test_scaled)
y_pred1 = np.argmax(y_pred1,axis=1)
# Labels de VGG16100
y_pred2 = modelpred2.predict(X_test_scaled)
y_pred2 = np.argmax(y_pred2,axis=1)
# Labels de ResNet50V2100
y_pred3 = modelpred3.predict(X_test_scaled)
y_pred3 = np.argmax(y_pred3,axis=1)
# Labels de ENV2B0100
y_pred4 = modelpred4.predict(X_test_scaled)
y_pred4 = np.argmax(y_pred4,axis=1)
# Labels de Personal
y_pred5 = modelpred5.predict(X_test_scaled)
y_pred5= np.argmax(y_pred5,axis=1)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 94s 2s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 30s 611ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
cnf = confusion_matrix(y_true, y_pred1)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('TesNet50')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred2)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('VGG16100')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred3)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('ResNet50')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred4)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('ENV2B0100')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)
cnf = confusion_matrix(y_true, y_pred5)
plt.figure(figsize=(8,6), dpi=70, facecolor='w', edgecolor='k')
ax = sns.heatmap(cnf, cmap='Blues', annot=True, fmt = 'd', xticklabels=labels, yticklabels=labels)
plt.title('Personalized')
plt.xlabel('Prediction')
plt.ylabel('Ground Truth')
plt.show(ax)

# %%
print('TesNet50' + classification_report(y_true, y_pred1))
print('-------------------------------------------------------------------------')
print('VGG16100' + classification_report(y_true, y_pred2))
print('-------------------------------------------------------------------------')
print('ResNet50' + classification_report(y_true, y_pred3))
print('-------------------------------------------------------------------------')
print('ENV2B' + classification_report(y_true, y_pred4))
print('-------------------------------------------------------------------------')
print('Personalized' + classification_report(y_true, y_pred5))
print('--------------------------------------------------')
# Out:
# TesNet50              precision    recall  f1-score   support
#
#            0       0.80      0.60      0.68       300
#            1       0.80      0.91      0.85       405
#            2       0.58      0.64      0.61       306
#            3       0.88      0.84      0.86       300
#
#     accuracy                           0.76      1311
#    macro avg       0.76      0.75      0.75      1311
# weighted avg       0.77      0.76      0.76      1311
#
# -------------------------------------------------------------------------
# VGG16100              precision    recall  f1-score   support
#
#            0       0.98      0.81      0.89       300
#            1       0.95      0.99      0.97       405
#            2       0.84      0.87      0.86       306
#            3       0.92      0.99      0.96       300
#
#     accuracy                           0.92      1311
#    macro avg       0.92      0.92      0.92      1311
# weighted avg       0.93      0.92      0.92      1311
#
# -------------------------------------------------------------------------
# ResNet50              precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90       300
#            1       0.98      0.99      0.99       405
#            2       0.87      0.86      0.86       306
#            3       0.90      0.98      0.94       300
#
#     accuracy                           0.93      1311
#    macro avg       0.92      0.92      0.92      1311
# weighted avg       0.93      0.93      0.93      1311
#
# -------------------------------------------------------------------------
# ENV2B              precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       300
#            1       0.99      0.99      0.99       405
#            2       0.88      0.94      0.91       306
#            3       0.93      1.00      0.96       300
#
#     accuracy                           0.95      1311
#    macro avg       0.95      0.95      0.95      1311
# weighted avg       0.95      0.95      0.95      1311
#
# -------------------------------------------------------------------------
# Personalized              precision    recall  f1-score   support
#
#            0       0.56      0.28      0.37       300
#            1       0.70      0.77      0.73       405
#            2       0.33      0.27      0.30       306
#            3       0.55      0.85      0.67       300
#
#     accuracy                           0.56      1311
#    macro avg       0.54      0.54      0.52      1311
# weighted avg       0.55      0.56      0.54      1311
#
# --------------------------------------------------

# %%
# Columnas de la tabla
t = PrettyTable(['Model', 'Accuracy', 'glioma','meningioma', 'notumor', 'pituitary'])
# To insert rows:
t.add_row(['TesNet50', 0.77,0.80,0.80,0.58,0.88])
t.add_row(['VGG16100', 0.93,0.98,0.95,0.84,0.92 ])
t.add_row(['ResNet50', 0.93,0.96,0.98,0.87,0.90])
t.add_row(['ENV2B', 0.95,0.99,0.99,0.88,0.93])
t.add_row(['Personalized', 0.55,0.56,0.70,0.33,0.55 ])
print(t)
# Out:
# +--------------+----------+--------+------------+---------+-----------+
# |    Model     | Accuracy | glioma | meningioma | notumor | pituitary |
# +--------------+----------+--------+------------+---------+-----------+
# |   TesNet50   |   0.77   |  0.8   |    0.8     |   0.58  |    0.88   |
# |   VGG16100   |   0.93   |  0.98  |    0.95    |   0.84  |    0.92   |
# |   ResNet50   |   0.93   |  0.96  |    0.98    |   0.87  |    0.9    |
# |    ENV2B     |   0.95   |  0.99  |    0.99    |   0.88  |    0.93   |
# | Personalized |   0.55   |  0.56  |    0.7     |   0.33  |    0.55   |
# +--------------+----------+--------+------------+---------+-----------+
